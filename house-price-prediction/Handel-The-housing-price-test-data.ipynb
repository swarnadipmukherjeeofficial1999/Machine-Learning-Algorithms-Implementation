# %%
#IMPORT LIBRABIES

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# READ THE TEST DATA 

house_price_test_data=pd.read_csv('test.csv')
house_price_test_data.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
# CHECK THE SHAPE 

house_price_test_data.shape
# Out:
# (1459, 80)

# %%
# CHECK THE NULL VALUES 


plt.figure(figsize=(15,10))
sns.heatmap(house_price_test_data.isnull())

# %%
# HANDLE THE NULL VALUES :

# %%
house_price_test_data['LotFrontage']=house_price_test_data['LotFrontage'].fillna(house_price_test_data['LotFrontage'].mean())

house_price_test_data['MSZoning']=house_price_test_data['MSZoning'].fillna(house_price_test_data['MSZoning'].mode()[0])

house_price_test_data.drop(['Alley'],axis=1,inplace=True)

house_price_test_data['BsmtCond']=house_price_test_data['BsmtCond'].fillna(house_price_test_data['BsmtCond'].mode()[0])

house_price_test_data['BsmtQual']=house_price_test_data['BsmtQual'].fillna(house_price_test_data['BsmtQual'].mode()[0])

house_price_test_data['FireplaceQu']=house_price_test_data['FireplaceQu'].fillna(house_price_test_data['FireplaceQu'].mode()[0])

house_price_test_data['GarageType']=house_price_test_data['GarageType'].fillna(house_price_test_data['GarageType'].mode()[0])

house_price_test_data.drop(['GarageYrBlt'],axis=1,inplace=True)

house_price_test_data['GarageFinish']=house_price_test_data['GarageFinish'].fillna(house_price_test_data['GarageFinish'].mode()[0])

house_price_test_data['GarageQual']=house_price_test_data['GarageQual'].fillna(house_price_test_data['GarageQual'].mode()[0])

house_price_test_data['GarageCond']=house_price_test_data['GarageCond'].fillna(house_price_test_data['GarageCond'].mode()[0])

house_price_test_data.drop(['PoolQC','Fence','MiscFeature'],axis=1,inplace=True)

house_price_test_data.drop(['Id'],axis=1,inplace=True)

house_price_test_data['MasVnrType']=house_price_test_data['MasVnrType'].fillna(house_price_test_data['MasVnrType'].mode()[0])

house_price_test_data['MasVnrArea']=house_price_test_data['MasVnrArea'].fillna(house_price_test_data['MasVnrArea'].mode()[0])

# %%
house_price_test_data.shape
# Out:
# (1459, 74)

# %%
plt.figure(figsize=(15,10))
sns.heatmap(house_price_test_data.isnull())

# %%
house_price_test_data['BsmtExposure']=house_price_test_data['BsmtExposure'].fillna(house_price_test_data['BsmtExposure'].mode()[0])

house_price_test_data['BsmtFinType2']=house_price_test_data['BsmtFinType2'].fillna(house_price_test_data['BsmtFinType2'].mode()[0])

# %%
plt.figure(figsize=(15,10))
sns.heatmap(house_price_test_data.isnull())

# %%
# CHECK FOR FURTHER NULL VALUES :

house_price_test_data.loc[:, house_price_test_data.isnull().any()].head()
# Out:
#   Utilities Exterior1st Exterior2nd BsmtFinType1  BsmtFinSF1  BsmtFinSF2  \
# 0    AllPub     VinylSd     VinylSd          Rec       468.0       144.0
# 1    AllPub     Wd Sdng     Wd Sdng          ALQ       923.0         0.0
# 2    AllPub     VinylSd     VinylSd          GLQ       791.0         0.0
# 3    AllPub     VinylSd     VinylSd          GLQ       602.0         0.0
# 4    AllPub     HdBoard     HdBoard          ALQ       263.0         0.0
#
#    BsmtUnfSF  TotalBsmtSF  BsmtFullBath  BsmtHalfBath KitchenQual Functional  \
# 0      270.0        882.0           0.0           0.0          TA        Typ
# 1      406.0       1329.0           0.0           0.0          Gd        Typ
# 2      137.0        928.0           0.0           0.0          TA        Typ
# 3      324.0        926.0           0.0           0.0          Gd        Typ
# 4     1017.0       1280.0           0.0           0.0          Gd        Typ
#
#    GarageCars  GarageArea SaleType
# ...

# %%
# HANDEL THOSE NULL VALUES :


house_price_test_data['Utilities']=house_price_test_data['Utilities'].fillna(house_price_test_data['Utilities'].mode()[0])
house_price_test_data['Exterior1st']=house_price_test_data['Exterior1st'].fillna(house_price_test_data['Exterior1st'].mode()[0])
house_price_test_data['Exterior2nd']=house_price_test_data['Exterior2nd'].fillna(house_price_test_data['Exterior2nd'].mode()[0])
house_price_test_data['BsmtFinType1']=house_price_test_data['BsmtFinType1'].fillna(house_price_test_data['BsmtFinType1'].mode()[0])
house_price_test_data['BsmtFinSF1']=house_price_test_data['BsmtFinSF1'].fillna(house_price_test_data['BsmtFinSF1'].mean())
house_price_test_data['BsmtFinSF2']=house_price_test_data['BsmtFinSF2'].fillna(house_price_test_data['BsmtFinSF2'].mean())
house_price_test_data['BsmtUnfSF']=house_price_test_data['BsmtUnfSF'].fillna(house_price_test_data['BsmtUnfSF'].mean())
house_price_test_data['TotalBsmtSF']=house_price_test_data['TotalBsmtSF'].fillna(house_price_test_data['TotalBsmtSF'].mean())
house_price_test_data['BsmtFullBath']=house_price_test_data['BsmtFullBath'].fillna(house_price_test_data['BsmtFullBath'].mode()[0])
house_price_test_data['BsmtHalfBath']=house_price_test_data['BsmtHalfBath'].fillna(house_price_test_data['BsmtHalfBath'].mode()[0])
house_price_test_data['KitchenQual']=house_price_test_data['KitchenQual'].fillna(house_price_test_data['KitchenQual'].mode()[0])
house_price_test_data['Functional']=house_price_test_data['Functional'].fillna(house_price_test_data['Functional'].mode()[0])
house_price_test_data['GarageCars']=house_price_test_data['GarageCars'].fillna(house_price_test_data['GarageCars'].mean())
house_price_test_data['GarageArea']=house_price_test_data['GarageArea'].fillna(house_price_test_data['GarageArea'].mean())
house_price_test_data['SaleType']=house_price_test_data['SaleType'].fillna(house_price_test_data['SaleType'].mode()[0])

# %%
# CHECK THE SHAPE 


house_price_test_data.shape
# Out:
# (1459, 74)

# %%
# CHECK FOR NULL VALUES AGAIN :

plt.figure(figsize=(15,10))
sns.heatmap(house_price_test_data.isnull())

# %%
house_price_test_data.loc[:, house_price_test_data.isnull().any()].head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
# NO NULL VALUES LEFT

# %%
house_price_test_data.to_csv('formulated_house_price_test_data.csv',index=False)
